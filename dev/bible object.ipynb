# %%
from py_kbible import kbible

# %%
b = kbible.KBible()
b.add("ASV")
b.add("WEB")
b.add("JA1955")
b.add("현대인의성경")

# %%
b.bystr("창1:1-5")
# Out:
#   book  chapter  verse                                               text  \
# 0    창        1      1                                태초에 하나님이 천지를 창조하시니라
# 1    창        1      2       땅이 혼돈하고 공허하며 흑암이 깊음 위에 있고 하나님의 신은 수면에 운행하시니라
# 2    창        1      3                        하나님이 가라사대 빛이 있으라 하시매 빛이 있었고
# 3    창        1      4               그 빛이 하나님의 보시기에 좋았더라 하나님이 빛과 어두움을 나누사
# 4    창        1      5  빛을 낮이라 칭하시고 어두움을 밤이라 칭하시니라 저녁이 되며 아침이 되니 이는 첫째...
# 0  Gen        1      1  In the beginning God created the heavens and t...
# 1  Gen        1      2  And the earth was waste and void; and darkness...
# 2  Gen        1      3  And God said, Let there be light: and there wa...
# 3  Gen        1      4  And God saw the light, that it was good: and G...
# 4  Gen        1      5  And God called the light Day, and the darkness...
# 0  Gen        1      1  In the beginning, God __a__FOOTNOTE__a__ Genes...
# 1  Gen        1      2  The earth was formless and empty. Darkness was...
# ...

# %%
print(b.bystr("창1:1,2", form="string"))
# Out:
# 태초에 하나님이 천지를 창조하시니라. 땅이 혼돈하고 공허하며 흑암이 깊음 위에 있고 하나님의 신은 수면에 운행하시니라
# In the beginning God created the heavens and the earth.. And the earth was waste and void; and darkness was upon the face of the deep: and the Spirit of God moved upon the face of the waters.
# In the beginning, God created the heavens and the earth.. The earth was formless and empty. Darkness was on the surface of the deep and God’s Spirit was hovering over the surface of the waters.
# はじめに神は天と地とを創造された。. 地は形なく、むなしく、やみが淵のおもてにあり、神の霊が水のおもてをおおっていた。
# 태초에 하나님이 우주를 창조하셨다.. 지구는 아무 형태도 없이 텅 비어 흑암에 싸인 채 물로 뒤덮여 있었고 하나님의 영은 수면이 활동하고 계셨다.

# %%
print(b.bystr("Gen1:1,2", form="md"))
# Out:
# `Gen1:1,2` 태초에 하나님이 천지를 창조하시니라. 땅이 혼돈하고 공허하며 흑암이 깊음 위에 있고 하나님의 신은 수면에 운행하시니라
# `Gen1:1,2` In the beginning God created the heavens and the earth.. And the earth was waste and void; and darkness was upon the face of the deep: and the Spirit of God[^1] moved upon the face of the waters.
# [^1]:  Genesis 1:2 Or, was brooding upon
# `Gen1:1,2` In the beginning, God[^1] created the heavens and the earth.. The earth was formless and empty. Darkness was on the surface of the deep and God’s Spirit was hovering over the surface of the waters.
# [^1]:  Genesis 1:1 The Hebrew word rendered “God” is “אֱלֹהִ֑ים” (Elohim).
# `Gen1:1,2` はじめに神は天と地とを創造された。. 地は形なく、むなしく、やみが淵のおもてにあり、神の霊が水のおもてをおおっていた。
# `Gen1:1,2` 태초에 하나님이 우주를 창조하셨다.. 지구는 아무 형태도 없이 텅 비어 흑암에 싸인 채 물로 뒤덮여 있었고 하나님의 영은 수면이 활동하고 계셨다.
